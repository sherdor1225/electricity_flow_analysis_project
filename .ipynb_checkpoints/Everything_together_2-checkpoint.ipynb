# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_excel('Cross_Border_totalflow_cleaned.xlsx', index_col=[0])
df.head()
# Out:
#                      Austria (AT) > Germany (DE)(TWh)  \
# Time
# 2020-01-01 01:00:00                               0.0
# 2020-01-01 02:00:00                               0.0
# 2020-01-01 03:00:00                               0.0
# 2020-01-01 04:00:00                               0.0
# 2020-01-01 05:00:00                               0.0
#
#                      Germany (DE) > Austria (AT)(TWh)  \
# Time
# 2020-01-01 01:00:00                          0.000826
# 2020-01-01 02:00:00                          0.000660
# 2020-01-01 03:00:00                          0.000404
# 2020-01-01 04:00:00                          0.000711
# 2020-01-01 05:00:00                          0.000754
#
#                      Belgium (BE) > Germany (DE)(TWh)  \
# Time
# 2020-01-01 01:00:00                               0.0
# 2020-01-01 02:00:00                               0.0
# 2020-01-01 03:00:00                               0.0
# 2020-01-01 04:00:00                               0.0
# ...

# %%
df_gener = pd.read_excel('Generation_per_hour_total.xlsx')
df_gener.tail()
# Out:
#            Date and Time  Biomass(TWh)  Fossil Brown coal/Lignite(TWh)  \
# 8779 2020-12-31 20:00:00      0.004606                        0.011374
# 8780 2020-12-31 21:00:00      0.004603                        0.011362
# 8781 2020-12-31 22:00:00      0.004594                        0.011458
# 8782 2020-12-31 23:00:00      0.004598                        0.011374
# 8783 2021-01-01 00:00:00      0.004600                        0.011416
#
#       Fossil Gas(TWh)  Fossil Hard coal(TWh)  Fossil Oil(TWh)  \
# 8779         0.007749               0.005254         0.000405
# 8780         0.007749               0.005251         0.000405
# 8781         0.007453               0.004846         0.000404
# 8782         0.007017               0.004629         0.000404
# 8783         0.006456               0.004187         0.000404
#
#       Geothermal(TWh)  Hydro Pumped Storage(TWh)  \
# 8779         0.000029                   0.004045
# 8780         0.000029                   0.001992
# ...

# %%
df_gener['Total Generation(TWh)'] = df_gener.sum(axis=1)
df_gener.head()
# Out:
#         Date and Time  Biomass(TWh)  Fossil Brown coal/Lignite(TWh)  \
# 0 2020-01-01 01:00:00      0.004862                        0.009317
# 1 2020-01-01 02:00:00      0.004844                        0.009419
# 2 2020-01-01 03:00:00      0.004842                        0.009426
# 3 2020-01-01 04:00:00      0.004844                        0.009497
# 4 2020-01-01 05:00:00      0.004832                        0.009550
#
#    Fossil Gas(TWh)  Fossil Hard coal(TWh)  Fossil Oil(TWh)  Geothermal(TWh)  \
# 0         0.004916               0.001962         0.000454          0.00003
# 1         0.004542               0.001825         0.000454          0.00003
# 2         0.004368               0.001797         0.000454          0.00003
# 3         0.004389               0.001899         0.000454          0.00003
# 4         0.004293               0.001922         0.000454          0.00003
#
#    Hydro Pumped Storage(TWh)  Hydro Run-of-river and poundage(TWh)  \
# ...

# %%
df_gener.drop(index=[8783])
# Out:
#            Date and Time  Biomass(TWh)  Fossil Brown coal/Lignite(TWh)  \
# 0    2020-01-01 01:00:00      0.004862                        0.009317
# 1    2020-01-01 02:00:00      0.004844                        0.009419
# 2    2020-01-01 03:00:00      0.004842                        0.009426
# 3    2020-01-01 04:00:00      0.004844                        0.009497
# 4    2020-01-01 05:00:00      0.004832                        0.009550
# ...                  ...           ...                             ...
# 8778 2020-12-31 19:00:00      0.004603                        0.011336
# 8779 2020-12-31 20:00:00      0.004606                        0.011374
# 8780 2020-12-31 21:00:00      0.004603                        0.011362
# 8781 2020-12-31 22:00:00      0.004594                        0.011458
# 8782 2020-12-31 23:00:00      0.004598                        0.011374
#
#       Fossil Gas(TWh)  Fossil Hard coal(TWh)  Fossil Oil(TWh)  \
# ...

# %%
gener_monthly = df_gener.resample('M', on='Date and Time').sum()

# %%
gener_monthly.index = gener_monthly.index.date

# %%
gener_monthly.tail()
# Out:
#             Biomass(TWh)  Fossil Brown coal/Lignite(TWh)  Fossil Gas(TWh)  \
# 2020-09-30      3.137835                        7.882320         4.751148
# 2020-10-31      3.351092                        9.237057         4.388863
# 2020-11-30      3.237483                        9.563434         5.932014
# 2020-12-31      3.371418                        8.807586         6.242645
# 2021-01-31      0.004600                        0.011416         0.006456
#
#             Fossil Hard coal(TWh)  Fossil Oil(TWh)  Geothermal(TWh)  \
# 2020-09-30               4.070415         0.318556         0.014260
# 2020-10-31               3.366076         0.320947         0.015561
# 2020-11-30               4.959296         0.335286         0.018010
# 2020-12-31               4.718257         0.324956         0.021087
# 2021-01-31               0.004187         0.000404         0.000030
#
#             Hydro Pumped Storage(TWh)  Hydro Run-of-river and poundage(TWh)  \
# ...

# %%
df_load = pd.read_excel('#Load_hourly_modified.xlsx')
df_load.tail()
# Out:
#                 Timestep  Day-ahead Forecast(TWh)  Actual Total Load(TWh)
# 8779 2020-12-31 20:00:00                 0.051581                0.055314
# 8780 2020-12-31 21:00:00                 0.049125                0.051240
# 8781 2020-12-31 22:00:00                 0.047388                0.048741
# 8782 2020-12-31 23:00:00                 0.047381                0.047598
# 8783 2021-01-01 00:00:00                 0.045866                0.045449

# %%
df_load.drop(index=[8783], inplace=True)

# %%
df_load_monthly = df_load.resample('M', on='Timestep').sum()

# %%
df_load_monthly.index = df_load_monthly.index.date

# %%
df_load_monthly.tail()
# Out:
#             Day-ahead Forecast(TWh)  Actual Total Load(TWh)
# 2020-08-31                37.390772               38.531094
# 2020-09-30                37.243973               38.763070
# 2020-10-31                41.270720               42.964595
# 2020-11-30                41.224663               43.052006
# 2020-12-31                41.407732               43.205600

# %%
data_daily = df.resample('D').sum()

# %%
data_monthly = df.resample('M').sum()

# %%
fig, ax = plt.subplots(figsize=(18, 6))


# define the shift
shift = pd.to_timedelta('5D')
barWidth = 5
# modify the base of each columns, can do with a for loop
ax.bar(data_monthly.index, data_monthly["Germany Export(TWh)"], width=barWidth, label='Total export') 
ax.bar(data_monthly.index + shift, data_monthly["Germany Import(TWh)"], width=barWidth, label='Total import')
#ax.bar(testdata.index - shift, testdata["C"])
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %D'))
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(18, 3))


# define the shift
shift = pd.to_timedelta('5D')
width=5
# modify the base of each columns, can do with a for loop
ax.bar(gener_monthly.index, gener_monthly['Total Generation(TWh)'], width, color='green', label='Total generation') 
ax.bar(df_load_monthly.index + shift, df_load_monthly["Actual Total Load(TWh)"], width, color='red', label='Total load')
#ax.bar(testdata.index - shift, testdata["C"])
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.legend()
plt.show()

# %%
df_flows = pd.read_excel('Cross_Border_totalflow_cleaned.xlsx', index_col=[0])
df_flows.head()
# Out:
#                      Austria (AT) > Germany (DE)(TWh)  \
# Time
# 2020-01-01 01:00:00                               0.0
# 2020-01-01 02:00:00                               0.0
# 2020-01-01 03:00:00                               0.0
# 2020-01-01 04:00:00                               0.0
# 2020-01-01 05:00:00                               0.0
#
#                      Germany (DE) > Austria (AT)(TWh)  \
# Time
# 2020-01-01 01:00:00                          0.000826
# 2020-01-01 02:00:00                          0.000660
# 2020-01-01 03:00:00                          0.000404
# 2020-01-01 04:00:00                          0.000711
# 2020-01-01 05:00:00                          0.000754
#
#                      Belgium (BE) > Germany (DE)(TWh)  \
# Time
# 2020-01-01 01:00:00                               0.0
# 2020-01-01 02:00:00                               0.0
# 2020-01-01 03:00:00                               0.0
# 2020-01-01 04:00:00                               0.0
# ...

# %%
df_flows_monthly = df_flows.resample('M').sum()

# %%
df_flows_monthly.index = df_flows_monthly.index.date

# %%
df_outflows_monthly = df_flows_monthly.iloc[:, 1:22:2]

# %%
df_outflows_monthly.head()
# Out:
#             Germany (DE) > Austria (AT)(TWh)  \
# 2020-01-31                          1.547060
# 2020-02-29                          1.374714
# 2020-03-31                          1.049168
# 2020-04-30                          0.663568
# 2020-05-31                          0.482198
#
#             Germany (DE) > Belgium (BE)(TWh)  \
# 2020-01-31                               0.0
# 2020-02-29                               0.0
# 2020-03-31                               0.0
# 2020-04-30                               0.0
# 2020-05-31                               0.0
#
#             Germany (DE) > Czech Republic (CZ)(TWh)  \
# 2020-01-31                                 1.051012
# 2020-02-29                                 0.843829
# 2020-03-31                                 0.766092
# 2020-04-30                                 0.689887
# 2020-05-31                                 0.662624
#
#             Germany (DE) > Denmark (DK)(TWh)  Germany (DE) > France (FR)(TWh)  \
# ...

# %%
df_inflows_monthly = df_flows_monthly.iloc[:, 0:21:2]

# %%
df_inflows_monthly.head()
# Out:
#             Austria (AT) > Germany (DE)(TWh)  \
# 2020-01-31                          0.000000
# 2020-02-29                          0.001599
# 2020-03-31                          0.038286
# 2020-04-30                          0.108195
# 2020-05-31                          0.143710
#
#             Belgium (BE) > Germany (DE)(TWh)  \
# 2020-01-31                               0.0
# 2020-02-29                               0.0
# 2020-03-31                               0.0
# 2020-04-30                               0.0
# 2020-05-31                               0.0
#
#             Czech Republic (CZ) > Germany (DE)(TWh)  \
# 2020-01-31                                 0.021732
# 2020-02-29                                 0.017376
# 2020-03-31                                 0.059171
# 2020-04-30                                 0.018328
# 2020-05-31                                 0.081822
#
#             Denmark (DK) > Germany (DE)(TWh)  France (FR) > Germany (DE)(TWh)  \
# ...

# %%
df_flows_monthly.tail()
# Out:
#             Austria (AT) > Germany (DE)(TWh)  \
# 2020-09-30                          0.175106
# 2020-10-31                          0.014626
# 2020-11-30                          0.002579
# 2020-12-31                          0.026983
# 2021-01-31                          0.000000
#
#             Germany (DE) > Austria (AT)(TWh)  \
# 2020-09-30                          0.538641
# 2020-10-31                          0.889704
# 2020-11-30                          1.215447
# 2020-12-31                          1.299115
# 2021-01-31                          0.000807
#
#             Belgium (BE) > Germany (DE)(TWh)  \
# 2020-09-30                          0.001415
# 2020-10-31                          0.014649
# 2020-11-30                          0.022818
# 2020-12-31                          0.083018
# 2021-01-31                          0.000000
#
#             Germany (DE) > Belgium (BE)(TWh)  \
# 2020-09-30                          0.000011
# ...

# %%
fig, ax = plt.subplots()

ax = df_inflows_monthly.plot.bar(stacked=True, figsize=(16,8), ax=ax, cmap='tab20')

ax.set_xticklabels([x.strftime("%Y-%m") for x in df_inflows_monthly.index])

ax.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)

ax.set_title("Imports by country")
plt.show()

# %%
fig, ax = plt.subplots()

ax = df_outflows_monthly.plot.bar(stacked=True, figsize=(16,8), ax=ax, cmap='tab20')

ax.set_xticklabels([x.strftime("%Y-%m") for x in df_outflows_monthly.index])

ax.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
ax.set_title("Exports by country")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,5)) # Create matplotlib figure

 #= fig.add_subplot() # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.2

df_flows_monthly['Germany Export(TWh)'].plot(kind='bar',  ax=ax, width=width, position=1, label='Export', color='green')
df_flows_monthly['Germany Import(TWh)'].plot(kind='bar',  ax=ax2, width=width, position=0, label='Import', color='red')

ax.set_ylabel('TWh')


ax.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
ax2.legend(bbox_to_anchor=(1.04,0.6), loc="center left", borderaxespad=0)
plt.title('Total export and import 2020')
plt.show()
#ax.set_xticklabels([x.strftime("%Y-%m") for x in df_inflows_monthly.index])

# %%
fig, ax = plt.subplots(figsize=(18, 3))


# define the shift
shift = pd.to_timedelta('5D')
width=5
# modify the base of each columns, can do with a for loop
ax.bar(gener_monthly.index, gener_monthly['Total Generation(TWh)'], width, color='green', label='Total generation') 
ax.bar(df_load_monthly.index + shift, df_load_monthly["Actual Total Load(TWh)"], width, color='red', label='Total load')
ax.bar(df_flows_monthly['Germany Import(TWh)'].index - shift, df_flows_monthly['Germany Import(TWh)'], width, color='blue', label='Total imports')
ax.bar(df_flows_monthly['Germany Export(TWh)'].index + 2*shift, df_flows_monthly['Germany Export(TWh)'], width, color='orange', label='Total exports')

#ax.bar(testdata.index - shift, testdata["C"])
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
ax.set_ylabel('TWh')
plt.title('Monthly comparison of generation, load, imports and exports')
plt.legend()
plt.show()
