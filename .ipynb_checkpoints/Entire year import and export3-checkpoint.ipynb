# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Cross_Border_totalflow_cleaned.xlsx')
df_new = pd.Series(pd.date_range(start='1/1/2020 00:00:00', end='31/12/2020 23:00:00', freq='1h'))
df1 = pd.concat([df_new, df], axis=1)
df1.drop(columns=['Time'], inplace=True)
df1.rename(columns={0: 'Timestep'}, inplace=True)
df1['Timestep']=pd.to_datetime(df1['Timestep'])
df1.set_index('Timestep', inplace=True)
df1.head()
# Out:
#                      Austria (AT) > Germany (DE)(TWh)  \
# Timestep
# 2020-01-01 00:00:00                               0.0
# 2020-01-01 01:00:00                               0.0
# 2020-01-01 02:00:00                               0.0
# 2020-01-01 03:00:00                               0.0
# 2020-01-01 04:00:00                               0.0
#
#                      Germany (DE) > Austria (AT)(TWh)  \
# Timestep
# 2020-01-01 00:00:00                          0.000826
# 2020-01-01 01:00:00                          0.000660
# 2020-01-01 02:00:00                          0.000404
# 2020-01-01 03:00:00                          0.000711
# 2020-01-01 04:00:00                          0.000754
#
#                      Belgium (BE) > Germany (DE)(TWh)  \
# Timestep
# 2020-01-01 00:00:00                               0.0
# 2020-01-01 01:00:00                               0.0
# 2020-01-01 02:00:00                               0.0
# 2020-01-01 03:00:00                               0.0
# ...

# %%
hourly_mean=df1.groupby(df1.index.hour).mean()*1000

# %%
hourly_mean_im = hourly_mean.iloc[:, 0:21:2]
hourly_mean_ex = hourly_mean.iloc[:, 1:22:2]

# %%
hourly_mean_im['Total'] = hourly_mean['Germany Import(TWh)']
hourly_mean_ex['Total'] = hourly_mean['Germany Export(TWh)']
# Out:
# C:\Users\User\Anaconda3\envs\master_project\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\Anaconda3\envs\master_project\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hourly_mean_ex.head()
# Out:
#           Germany (DE) > Austria (AT)(TWh)  Germany (DE) > Belgium (BE)(TWh)  \
# Timestep
# 0                                 1.179724                          0.039827
# 1                                 1.221637                          0.047761
# 2                                 1.221541                          0.043567
# 3                                 1.186131                          0.044544
# 4                                 1.165519                          0.038380
#
#           Germany (DE) > Czech Republic (CZ)(TWh)  \
# Timestep
# 0                                        0.527645
# 1                                        0.520997
# 2                                        0.512489
# 3                                        0.515896
# 4                                        0.562724
#
#           Germany (DE) > Denmark (DK)(TWh)  Germany (DE) > France (FR)(TWh)  \
# Timestep
# 0                                 0.171626                         0.254609
# ...

# %%
hourly_mean_im.head()
# Out:
#           Austria (AT) > Germany (DE)(TWh)  Belgium (BE) > Germany (DE)(TWh)  \
# Timestep
# 0                                 0.069030                          0.006512
# 1                                 0.059432                          0.007198
# 2                                 0.064527                          0.004545
# 3                                 0.064667                          0.006560
# 4                                 0.078650                          0.010092
#
#           Czech Republic (CZ) > Germany (DE)(TWh)  \
# Timestep
# 0                                        0.336279
# 1                                        0.354164
# 2                                        0.364932
# 3                                        0.348995
# 4                                        0.307363
#
#           Denmark (DK) > Germany (DE)(TWh)  France (FR) > Germany (DE)(TWh)  \
# Timestep
# 0                                 0.887896                         0.995219
# ...

# %%
fig_15 = plt.figure(figsize=(18,8))

axes_15 = fig_15.add_axes([0.0, 0.0, 0.9, 0.9])




sns.histplot(hourly_mean_ex,  x = hourly_mean_ex['Total'], kde=True)


# axes_14.set_xticks(np.arange(2.5, 6, 1))
sns.set_style("darkgrid")
# sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
fig_14 = plt.figure(figsize=(18,8))

axes_14 = fig_14.add_axes([0.0, 0.0, 0.9, 0.9])




sns.histplot(hourly_mean_im, x = hourly_mean_im['Total'], bins= 20)


# axes_14.set_xticks(np.arange(2.5, 6, 1))
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
fig_13 = plt.figure(figsize=(12,6))

axes_13 = fig_13.add_axes([0.0, 0.0, 0.9, 0.9])




sns.histplot(hourly_mean_im, x = hourly_mean_im['France (FR) > Germany (DE)(TWh)'], bins=15, kde=True, color='r')
axes_13.set_title('Yearly Cross-border import by the hour of the day from FR to DE')
axes_13.set_xlabel('FR > DE (GWh)')

# axes_14.set_xticks(np.arange(2.5, 6, 1))
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
fig_13 = plt.figure(figsize=(12,6))

axes_13 = fig_13.add_axes([0.0, 0.0, 0.9, 0.9])




sns.histplot(hourly_mean_ex, x = hourly_mean_ex['Germany (DE) > France (FR)(TWh)'], bins=15, kde=True, color='green')
axes_13.set_xlabel('DE > FR (GWh)')
axes_13.set_title('Yearly Cross-border export by the hour of the day from DE to FR')
# axes_14.set_xticks(np.arange(2.5, 6, 1))
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
fig_5=plt.figure(figsize=(18,8))

axes_5 = fig_5.add_axes([0.0, 0.0, 0.9, 0.9])
sns.histplot(hourly_mean_ex,  stat="probability", common_norm=False, palette = 'icefire', 
             multiple='stack',legend=False, binwidth=0.1)
#axes_5.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
